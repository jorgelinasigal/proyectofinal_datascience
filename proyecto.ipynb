# %%
import pandas as pd
import numpy as np

# %%
remuneraciones = pd.read_csv('Remuneraciones.csv', header=[0, 1])

# %%
remuneraciones
# Out:
#      Período (mes año)          Agricultura y ganadería Unnamed: 2_level_0  \
#     Unnamed: 0_level_1                          Mujeres            Varones
# 0               ene-96                            380.2              399.8
# 1               feb-96                            406.8              398.1
# 2               mar-96                            399.7              393.3
# 3               abr-96                            375.9              394.6
# 4               may-96                            395.6              389.8
# ..                 ...                              ...                ...
# 327                NaN                              NaN                NaN
# 328                NaN                            OEDE                 NaN
# 329                NaN                             SIPA                NaN
# 330                NaN                Tasa de femenidad                NaN
# ...

# %%
# Eliminar columnas "Unnamed"
remuneraciones = remuneraciones.loc[:, ~remuneraciones.columns.get_level_values(0).str.contains('Unnamed', na=False)]

# %%
remuneraciones
# Out:
#      Período (mes año)          Agricultura y ganadería  \
#     Unnamed: 0_level_1                          Mujeres
# 0               ene-96                            380.2
# 1               feb-96                            406.8
# 2               mar-96                            399.7
# 3               abr-96                            375.9
# 4               may-96                            395.6
# ..                 ...                              ...
# 327                NaN                              NaN
# 328                NaN                            OEDE
# 329                NaN                             SIPA
# 330                NaN                Tasa de femenidad
# 331                NaN  Trabajadores Registrados (SIPA)
#
#     Silvicultura, extracción de madera  \
#                                Mujeres
# 0                                426.2
# 1                                416.0
# 2                                416.5
# ...
